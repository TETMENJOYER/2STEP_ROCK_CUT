# %%
import PSO_for_cuts_pc as pso
import TS_for_cuts_pc as ts
import block_interactions as bi 
import pyvista as pv
import numpy as np

# %%
block = pv.Sphere(radius=1.0, theta_resolution=30, phi_resolution=30)

# %%
slices =  bi.slice_polygon_by_height(block,0.3)
for i in range(slices)
print(slices)
for i in range(len(slices)):
    slice_solution = ts.TS_opt_full()
